# %% [markdown]
# <a href="https://colab.research.google.com/github/dhawall-s/Analog_Clock/blob/main/dhawal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import cv2 as cv
import matplotlib.pyplot as plt
img=cv.imread('messi.jpeg')

# %%
img
# Out:
# array([[[  8,   3,   4],
#         [  9,   4,   5],
#         [  9,   4,   5],
#         ...,
#         [  2,   2,   2],
#         [  2,   2,   2],
#         [  2,   2,   2]],
#
#        [[  8,   3,   4],
#         [  8,   3,   4],
#         [  9,   4,   5],
#         ...,
#         [  2,   2,   2],
#         [  2,   2,   2],
#         [  2,   2,   2]],
#
#        [[  8,   3,   4],
#         [  8,   3,   4],
#         [  8,   3,   4],
#         ...,
#         [  2,   2,   2],
#         [  2,   2,   2],
#         [  2,   2,   2]],
#
#        ...,
#
#        [[ 37,  16,  19],
#         [ 43,  22,  25],
#         [ 48,  26,  31],
#         ...,
#         [171, 166, 167],
#         [180, 175, 176],
#         [187, 182, 183]],
#
#        [[ 46,  25,  27],
#         [ 40,  19,  21],
#         [ 32,  11,  14],
#         ...,
#         [154, 148, 149],
#         [170, 164, 165],
#         [177, 171, 172]],
#
#        [[ 39,  18,  20],
#         [ 35,  14,  16],
#         [ 32,  11,  14],
# ...

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (168, 300, 3)

# %%
plt.xlabel('168')
plt.ylabel('300')
plt.title('ankara messi')
plt.imshow(img)

# %%
import cv2 as cv

# %%
img_grey=cv.cvtColor(img,cv.COLOR_BGR2GRAY)
plt.imshow(img_grey)

# %%
img_rgb=cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
img_bgr=cv.cvtColor(img,cv.COLOR_RGB2BGR)
plt.imshow(img_bgr)

# %%
b_image=img[:,:,0]
plt.subplot(221)
plt.imshow(img_rgb)
r_image=img[:,:,1]
plt.subplot(222)
plt.imshow(img_bgr)
g_image=img[:,:,2]
plt.subplot(223)
plt.imshow(img_grey)
q_image=img
plt.subplot(224)
plt.imshow(img)

# %%
img1=cv.cvtColor(img_grey,cv.COLOR_GRAY2RGB)
plt.imshow(img1)
